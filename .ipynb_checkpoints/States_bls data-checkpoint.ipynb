# %%
# Importing the modules required.
import pandas as pd
import numpy as np
import json
import requests
import matplotlib.pyplot as plt
from key import api_key

url = "https://api.bls.gov/publicAPI/v2/timeseries/data/"

states_pd = pd.read_csv("Resources/states.csv")
series_ids = states_pd["Series Id"].tolist()
start_year = "1996"
end_year = "2014"
header = {"Content-Type": "application/json"}

payload = json.dumps({"seriesid":series_ids,
                     "startyear":start_year,
                     "endyear":end_year,
                      "registrationkey":api_key                      
                      })

state_response1 = requests.post(url,headers=header,data=payload).json()['Results']['series']
state_response1
# Out:
# [{'seriesID': 'LASST010000000000003',
#   'data': [{'year': '2014',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '8.1',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '8.2',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '8.3',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '8.2',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '8.1',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '8.1',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '8.3',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '8.6',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '9.0',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '9.4',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '9.7',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '9.9',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '10.0',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '10.0',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '10.0',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '10.1',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '10.2',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '10.2',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '10.3',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '10.2',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '10.1',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '10.0',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '9.9',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '10.0',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '10.1',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '10.4',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '10.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '11.4',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '11.6',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '11.7',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '11.8',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '11.8',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '11.8',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '11.7',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '11.6',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '11.5',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '11.3',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '11.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '10.7',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '10.2',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '9.6',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '8.9',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '8.1',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.3',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.2',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.0',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '3.9',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '3.8',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '3.8',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '3.8',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '3.8',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '3.8',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '3.9',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '3.9',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.0',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.0',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.2',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.2',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.7',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.2',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.2',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.3',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.4',
#     'footnotes': [{}]}]},
#  {'seriesID': 'LASST020000000000003',
#   'data': [{'year': '2014',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2014',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2013',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2012',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2011',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2010',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '8.0',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2009',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2008',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.5',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.4',
#     'footnotes': [{}]},
# ...
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.4',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.5',
#     'footnotes': [{}]},
#    {'year': '2007',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.6',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2006',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '4.7',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2005',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.3',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2004',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.7',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.7',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '2003',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.1',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.9',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.7',
#     'footnotes': [{}]},
#    {'year': '2002',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.3',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '4.8',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '4.9',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.0',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.1',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.2',
#     'footnotes': [{}]},
#    {'year': '2001',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.3',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '5.4',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '5.5',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '5.6',
#     'footnotes': [{}]},
#    {'year': '2000',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '5.8',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.0',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.2',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.3',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1999',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.4',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.5',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.6',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1998',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '6.7',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '6.8',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '6.9',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.1',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '1997',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M12',
#     'periodName': 'December',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M11',
#     'periodName': 'November',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M10',
#     'periodName': 'October',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M09',
#     'periodName': 'September',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M08',
#     'periodName': 'August',
#     'value': '7.2',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M07',
#     'periodName': 'July',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M06',
#     'periodName': 'June',
#     'value': '7.3',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M05',
#     'periodName': 'May',
#     'value': '7.4',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M04',
#     'periodName': 'April',
#     'value': '7.6',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M03',
#     'periodName': 'March',
#     'value': '7.7',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M02',
#     'periodName': 'February',
#     'value': '7.9',
#     'footnotes': [{}]},
#    {'year': '1996',
#     'period': 'M01',
#     'periodName': 'January',
#     'value': '8.0',
#     'footnotes': [{}]}]}]

# %%
states1_df = pd.DataFrame(columns=['year','period','periodName','value','footnotes','Stateid'])

for i in range(0, len(state_response1)):
     seriesDF= pd.DataFrame(state_response1[i]['data'])
     seriesDF["Stateid"] = state_response1[i]["seriesID"]
     states1_df = states1_df.append(seriesDF, ignore_index = True)

states1_df
# Out:
#        year period periodName value footnotes               Stateid
# 0      2014    M12   December   6.1      [{}]  LASST010000000000003
# 1      2014    M11   November   6.2      [{}]  LASST010000000000003
# 2      2014    M10    October   6.4      [{}]  LASST010000000000003
# 3      2014    M09  September   6.5      [{}]  LASST010000000000003
# 4      2014    M08     August   6.6      [{}]  LASST010000000000003
# ...     ...    ...        ...   ...       ...                   ...
# 11395  1996    M05        May   7.4      [{}]  LASST540000000000003
# 11396  1996    M04      April   7.6      [{}]  LASST540000000000003
# 11397  1996    M03      March   7.7      [{}]  LASST540000000000003
# 11398  1996    M02   February   7.9      [{}]  LASST540000000000003
# 11399  1996    M01    January   8.0      [{}]  LASST540000000000003
#
# [11400 rows x 6 columns]

# %%
start_year = "2015"
end_year = "2016"
header = {"Content-Type": "application/json"}
payload = json.dumps({"seriesid":series_ids,
                     "startyear":start_year,
                     "endyear":end_year,
                      "registrationkey":api_key                      
                      })

state_response2 = requests.post(url,headers=header,data=payload).json()['Results']['series']

states2_df = pd.DataFrame(columns=['year','period','periodName','value','footnotes','Stateid'])

for i in range(0, len(state_response2)):
     seriesDF= pd.DataFrame(state_response2[i]['data'])
     seriesDF["Stateid"] = state_response2[i]["seriesID"]
     states2_df = states2_df.append(seriesDF, ignore_index = True)

states2_df
# Out:
#       year period periodName value footnotes               Stateid
# 0     2016    M12   December   5.7      [{}]  LASST010000000000003
# 1     2016    M11   November   5.8      [{}]  LASST010000000000003
# 2     2016    M10    October   5.9      [{}]  LASST010000000000003
# 3     2016    M09  September   5.9      [{}]  LASST010000000000003
# 4     2016    M08     August   5.8      [{}]  LASST010000000000003
# ...    ...    ...        ...   ...       ...                   ...
# 1195  2015    M05        May   7.0      [{}]  LASST540000000000003
# 1196  2015    M04      April   7.0      [{}]  LASST540000000000003
# 1197  2015    M03      March   6.9      [{}]  LASST540000000000003
# 1198  2015    M02   February   6.8      [{}]  LASST540000000000003
# 1199  2015    M01    January   6.6      [{}]  LASST540000000000003
#
# [1200 rows x 6 columns]

# %%
dataframes = [states2_df,states1_df]
states_df = pd.concat(dataframes)
states_df
# Out:
#        year period periodName value footnotes               Stateid
# 0      2016    M12   December   5.7      [{}]  LASST010000000000003
# 1      2016    M11   November   5.8      [{}]  LASST010000000000003
# 2      2016    M10    October   5.9      [{}]  LASST010000000000003
# 3      2016    M09  September   5.9      [{}]  LASST010000000000003
# 4      2016    M08     August   5.8      [{}]  LASST010000000000003
# ...     ...    ...        ...   ...       ...                   ...
# 11395  1996    M05        May   7.4      [{}]  LASST540000000000003
# 11396  1996    M04      April   7.6      [{}]  LASST540000000000003
# 11397  1996    M03      March   7.7      [{}]  LASST540000000000003
# 11398  1996    M02   February   7.9      [{}]  LASST540000000000003
# 11399  1996    M01    January   8.0      [{}]  LASST540000000000003
#
# [12600 rows x 6 columns]

# %%
states_df = states_df.loc[(states_df['period'] == 'M12')|(states_df['period'] == 'M01')].reset_index(drop=True)
states_df=states_df.drop('footnotes', axis=1)
states_df
# Out:
#       year period periodName value               Stateid
# 0     2016    M12   December   5.7  LASST010000000000003
# 1     2016    M01    January   6.0  LASST010000000000003
# 2     2015    M12   December   6.0  LASST010000000000003
# 3     2015    M01    January   6.0  LASST010000000000003
# 4     2016    M12   December   6.9  LASST020000000000003
# ...    ...    ...        ...   ...                   ...
# 2095  1998    M01    January   6.7  LASST540000000000003
# 2096  1997    M12   December   6.7  LASST540000000000003
# 2097  1997    M01    January   7.3  LASST540000000000003
# 2098  1996    M12   December   7.4  LASST540000000000003
# 2099  1996    M01    January   8.0  LASST540000000000003
#
# [2100 rows x 5 columns]

# %%
states_df['value'] = states_df['value'].astype(float)
state_yearlychange_df = pd.DataFrame(columns=['Series Id','year','yearlyChange'])

for i in states_df.index:       
    if i%2==0:
        yearly_change = states_df['value'][i] - states_df['value'][i+1]
        stateid = states_df['Stateid'][i]
        year = states_df['year'][i]
        state_yearlychange_df = state_yearlychange_df.append({'Series Id':stateid,
                                                             'year': year,
                                                             'yearlyChange':yearly_change
                                                             },ignore_index=True)

        
state_yearlychange_df
# Out:
#                  Series Id  year  yearlyChange
# 0     LASST010000000000003  2016          -0.3
# 1     LASST010000000000003  2015           0.0
# 2     LASST020000000000003  2016           0.2
# 3     LASST020000000000003  2015           0.2
# 4     LASST040000000000003  2016          -0.4
# ...                    ...   ...           ...
# 1045  LASST540000000000003  2000          -0.4
# 1046  LASST540000000000003  1999          -0.5
# 1047  LASST540000000000003  1998          -0.3
# 1048  LASST540000000000003  1997          -0.6
# 1049  LASST540000000000003  1996          -0.6
#
# [1050 rows x 3 columns]

# %%
state_year_df = pd.merge(states_pd,state_yearlychange_df, on='Series Id')
state_year_df
# Out:
#                   STATES             Series Id  year  yearlyChange
# 0           Alabama (AL)  LASST010000000000003  2016          -0.3
# 1           Alabama (AL)  LASST010000000000003  2015           0.0
# 2           Alabama (AL)  LASST010000000000003  2014          -1.1
# 3           Alabama (AL)  LASST010000000000003  2013          -0.2
# 4           Alabama (AL)  LASST010000000000003  2012          -0.5
# ...                  ...                   ...   ...           ...
# 1045  West Virginia (WV)  LASST540000000000003  2000          -0.4
# 1046  West Virginia (WV)  LASST540000000000003  1999          -0.5
# 1047  West Virginia (WV)  LASST540000000000003  1998          -0.3
# 1048  West Virginia (WV)  LASST540000000000003  1997          -0.6
# 1049  West Virginia (WV)  LASST540000000000003  1996          -0.6
#
# [1050 rows x 4 columns]

# %%
state_year_group_df = state_year_df.groupby(['STATES','Series Id','year']).sum()
state_year_group_df.tail(59)
# Out:
#                                               yearlyChange
# STATES             Series Id            year
# Virginia (VA)      LASST510000000000003 2000          -0.4
#                                         2001           1.9
#                                         2002           0.0
#                                         2003          -0.3
#                                         2004          -0.2
#                                         2005          -0.4
#                                         2006          -0.2
#                                         2007           0.4
#                                         2008           1.7
#                                         2009           1.9
#                                         2010          -0.6
#                                         2011          -0.3
#                                         2012          -0.5
#                                         2013          -0.3
#                                         2014          -0.6
#                                         2015          -0.8
#                                         2016           0.0
# Washington (WA)    LASST530000000000003 1996          -0.9
#                                         1997          -0.7
#                                         1998           0.2
#                                         1999           0.1
#                                         2000           0.5
#                                         2001           1.7
#                                         2002          -0.1
#                                         2003          -0.4
#                                         2004          -1.1
#                                         2005          -0.6
#                                         2006          -0.2
#                                         2007          -0.1
#                                         2008           2.0
#                                         2009           3.3
#                                         2010          -0.7
#                                         2011          -0.8
#                                         2012          -1.2
#                                         2013          -0.8
#                                         2014          -0.7
#                                         2015          -0.3
#                                         2016          -0.6
# West Virginia (WV) LASST540000000000003 1996          -0.6
#                                         1997          -0.6
#                                         1998          -0.3
#                                         1999          -0.5
#                                         2000          -0.4
#                                         2001           0.0
#                                         2002           0.6
#                                         2003          -0.4
#                                         2004          -0.4
#                                         2005          -0.4
#                                         2006           0.1
#                                         2007           0.0
#                                         2008           0.8
#                                         2009           2.7
#                                         2010           0.2
#                                         2011          -1.2
#                                         2012           0.0
#                                         2013          -0.5
#                                         2014          -0.4
#                                         2015          -0.2
#                                         2016          -0.9

# %%
state_year_group_df.to_csv("Resources/state_1996-2016.csv")
